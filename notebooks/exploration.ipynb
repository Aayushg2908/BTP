# %% [markdown]
# # Data Exploration and Analysis
#
# This notebook explores the Google Speech Commands dataset and analyzes the MFCC features.

# %%
import sys
sys.path.append('..')

import numpy as np
import matplotlib.pyplot as plt
import librosa
from pathlib import Path

from src.data_loader import SpeechCommandsDataset
from src.feature_extraction import extract_mfcc

# %% [markdown]
# ## Load Dataset

# %%
# Load dataset
data_dir = '../data/speech_commands_v0.02'
dataset = SpeechCommandsDataset(data_dir, split='train')

print(f"Dataset size: {len(dataset)}")
print(f"Number of classes: {dataset.num_classes}")
print(f"Classes: {sorted(dataset.label_map.keys())}")
